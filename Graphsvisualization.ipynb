# %% [markdown]
# <a href="https://colab.research.google.com/github/RaviralaLathasri/numpybasics/blob/main/Graphsvisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#scatter plots
x_data=np.random.random(50)*100    #every time you run it gives the different outputs because it takes the random integers
y_data=np.random.random(50)*100    # 50 random floating-point numbers, each of which is between 0 and 100 (inclusive of 0 but exclusive of 100).
plt.scatter(x_data,y_data,c="green",marker="*",s=100)  #if you give c="green",it gives you the green colour
                                                                   # s=100,it gives you  the size which you mensioned

# %%
x_year=[2006+x for x in range(16)]
y_weights=[23,34,3,36,37,38,39,40,45,46,47,52,54,56,58,40]
print(len(y_weights))
plt.plot(x_year,y_weights,lw=3,linestyle="--")     #lw(line weidth  of the output)
# Out:
# 16

# %%
#bar plots
x= ["c","c#","c++","python","java"]
y=[50,23,35,21,11]
plt.bar(x,y,align="edge",width=0.5,edgecolor="red",lw=5)      #it shows you the point where the bar starts
# Out:
# <BarContainer object of 5 artists>

# %%
ages=np.random.normal(20,1.5,1000)      #generates random numbers from a normal (Gaussian) distribution.20=mean,1.5=sd,1000=range of no.(0,1000)
plt.hist(ages,bins=20,cumulative="true")
# Out:
# (array([   3.,    5.,   15.,   32.,   70.,  123.,  196.,  303.,  437.,
#          564.,  688.,  796.,  869.,  930.,  966.,  989.,  995.,  997.,
#          999., 1000.]),
#  array([15.34179196, 15.82852846, 16.31526495, 16.80200145, 17.28873794,
#         17.77547444, 18.26221093, 18.74894743, 19.23568392, 19.72242042,
#         20.20915691, 20.69589341, 21.1826299 , 21.6693664 , 22.15610289,
#         22.64283939, 23.12957588, 23.61631238, 24.10304887, 24.58978537,
#         25.07652186]),
#  <BarContainer object of 20 artists>)

# %%
x= ["c","c#","c++","python","java"]
y=[50,23,35,21,11]
explodes=[0.1,0,0,0,0,]
plt.pie(y,labels=x,explode=explodes,autopct="%.2f%%",pctdistance=1.4,startangle=90) #autopct gives the percentage in flote
                                                          #pichart distance#startangle means it starts the sector from 0 degree and moves left
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3b1887fc10>,
# ...
#  [Text(-1.0811626554108318, 0.5206604580194265, 'c'),
#   Text(-0.4095229532353692, -1.0209265158538012, 'c#'),
#   Text(0.875187060812217, -0.666368973307486, 'c++'),
#   Text(0.9042022176388531, 0.626433036817967, 'python'),
#   Text(0.26877430622345666, 1.0666585078243644, 'java')],
#  [Text(-1.3514533192635398, 0.6508255725242831, '35.71%'),
#   Text(-0.5212110313904699, -1.299361020177565, '16.43%'),
#   Text(1.1138744410337307, -0.8481059660277093, '25.00%'),
#   Text(1.1508028224494493, 0.7972784104955942, '15.00%'),
#   Text(0.3420763897389448, 1.3575653735946454, '7.86%')])

# %%
#boxplot
heights=np.random.normal(172,23,300)
plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f3b185d9310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f3b185daa10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f3b1887ba50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3b185e41d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3b185e4d50>],
#  'means': []}

# %%
import matplotlib.pyplot as plt

year = [2015, 2016, 2017, 2018, 2019, 2020, 2021]
income = [51, 56, 57, 68, 69, 71, 75]
income_tickets = list(range(50, 81, 2))

plt.plot(year, income, marker='o', linestyle='-', color='b', label="John's Income")  # Added markers and label
plt.title("Income of John in USD Dollars", fontsize=20)  # Fixed title
plt.xlabel("Year", fontsize=14)
plt.ylabel("Income (in thousands USD)", fontsize=14)
plt.yticks(income_tickets, [f"{x}k USD" for x in income_tickets])  # Fixed yticks
plt.xticks(year)  # Ensuring all years are labeled
plt.legend()  # Display legend
plt.grid(True, linestyle='--', alpha=0.7)  # Adding grid for better readability

plt.show()

# %%
#legents and multiple plots
stock_a=[12,34,45,65,67,34,54]
stock_b=[34,42,35,46,57,89,23]
stock_c=[34,56,76,87,23,45,53]
plt.plot(stock_a,label="company1")        #if you wont mension th x axis data,then it takes the random data
plt.plot(stock_b,label="company2")
plt.plot(stock_c,label="company3")
plt.legend(loc="lower center")

# %%
#legends used in piechart
import matplotlib.pyplot as plt
votes=[2,6,5,7]
people=['a','b','c','d']
plt.pie(votes,labels=None)
plt.legend(labels=people)

# %%
#styling
import matplotlib.pyplot as plt
#from matplotlib import style
#style.use("dark_background")     #here you gets the dark background
votes=[2,6,5,7]
people=['a','b','c','d']
plt.pie(votes,labels=None)
plt.legend(labels=people)

# %%
#to get multiple figures
import matplotlib.pyplot as plt
import numpy as np
x_data=np.random.random(50)*100
y_data=np.random.random(50)*100
plt.figure(1)
plt.scatter(x_data,y_data)
x=np.arange(100)
y=np.random.random(100)
plt.figure(2)
plt.plot(x,y)

# %%
#subplots
x = np.arange(100)

fig, axs= plt.subplots (2, 2)

axs [0, 0].plot(x, np.sin(x))

axs [0, 0].set_title("Sine Wave")
axs [0, 1].plot(x, np.cos(x))

axs[0, 1].set_title("Cosine Wave")
axs[1, 0].plot(x, np.random.random(100))

axs[1, 0].set_title("Random Function")
axs [1, 1].plot(x, np.log(x))

axs [1, 1].set_title("Log Function")
axs [1, 1].set_xlabel("TEST")

fig.suptitle("Four Plots")
plt.tight_layout()                    #it removes the overlapping of lables
#exporting plots
plt.savefig("fourplots.png",dpi=300,transparent=False)    #dpi means to get the high quality
# Out:
# <ipython-input-15-acd73b2c5835>:15: RuntimeWarning: divide by zero encountered in log
#   axs [1, 1].plot(x, np.log(x))

# %%
#3D Ploting
import numpy as np
import matplotlib.pyplot as plt

ax = plt.axes(projection="3d")

x = np.random.random(100)
y = np.random.random(100)
z = np.random.random(100)

ax.scatter(x, y, z)

ax.set_title("3D Plot")
# Out:
# Text(0.5, 0.92, '3D Plot')

# %%
 #Depict the sales for the three weeks using a Line chart. It should have the following:
 #i.   Chart title as “Mela Sales Report”.
 #ii.  axis label as Days.
 #iii. axis label as “Sales in Rs”.
 #Line colours are red for week 1, blue for week 2 and brown for week 3
 week1=[5000,5900,6500,3500,4000,5300,7900]
 week2=[ 4000,3000,5000, 5500,3000,4300,5900]
 week3=[3000,4000,2500,50000,4500,3500,4000]
 plt.plot(week1,week2,week3)
